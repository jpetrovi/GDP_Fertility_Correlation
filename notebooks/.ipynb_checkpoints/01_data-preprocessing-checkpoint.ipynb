# %%
import pandas as pd
from IPython.display import display

RAW_DATA_DIR = '../data/raw'
PROCESSED_DATA_FILENAME = '../data/processed/gdp_fertility.csv'

FERTILITY_RATES = RAW_DATA_DIR + '/API_SP.DYN.TFRT.IN_DS2_EN_csv_v2_2163843.csv'
GDPS = RAW_DATA_DIR + '/API_NY.GDP.PCAP.PP.CD_DS2_en_csv_v2_2183937.csv'

fert_df = pd.read_csv(FERTILITY_RATES, header=2)
fert_df = fert_df[['Country Name', '2016']]
fert_df = fert_df[fert_df['2016'].notnull()]
gdps_df = pd.read_csv(GDPS, header = 2)
gdps_df = gdps_df[['Country Name', '2016']]
gdps_df = gdps_df[gdps_df['2016'].notnull()]
fert_df.rename(columns={'2016' : 'fertility'}, inplace=True)
gdps_df.rename(columns={'2016': 'gdp'}, inplace=True)
merged_df = pd.merge(fert_df, gdps_df, on='Country Name')
merged_df = merged_df[merged_df['fertility'].notnull()]
merged_df = merged_df[merged_df['gdp'].notnull()]
merged_df.to_csv(PROCESSED_DATA_FILENAME, sep=',', index=False)
# Out:
#      Country Name Country Code                                 Indicator Name  \
# 0           Aruba          ABW  GDP per capita, PPP (current international $)
# 1     Afghanistan          AFG  GDP per capita, PPP (current international $)
# 2          Angola          AGO  GDP per capita, PPP (current international $)
# 3         Albania          ALB  GDP per capita, PPP (current international $)
# 4         Andorra          AND  GDP per capita, PPP (current international $)
# ..            ...          ...                                            ...
# 259        Kosovo          XKX  GDP per capita, PPP (current international $)
# 260   Yemen, Rep.          YEM  GDP per capita, PPP (current international $)
# 261  South Africa          ZAF  GDP per capita, PPP (current international $)
# 262        Zambia          ZMB  GDP per capita, PPP (current international $)
# 263      Zimbabwe          ZWE  GDP per capita, PPP (current international $)
#
#         Indicator Code  1960  1961  1962  1963  1964  1965  ...          2012  \
# 0    NY.GDP.PCAP.PP.CD   NaN   NaN   NaN   NaN   NaN   NaN  ...  33569.186501
# 1    NY.GDP.PCAP.PP.CD   NaN   NaN   NaN   NaN   NaN   NaN  ...   1914.774351
# 2    NY.GDP.PCAP.PP.CD   NaN   NaN   NaN   NaN   NaN   NaN  ...   7412.965263
# 3    NY.GDP.PCAP.PP.CD   NaN   NaN   NaN   NaN   NaN   NaN  ...  10526.318974
# 4    NY.GDP.PCAP.PP.CD   NaN   NaN   NaN   NaN   NaN   NaN  ...           NaN
# ..                 ...   ...   ...   ...   ...   ...   ...  ...           ...
# 259  NY.GDP.PCAP.PP.CD   NaN   NaN   NaN   NaN   NaN   NaN  ...   8477.469769
# 260  NY.GDP.PCAP.PP.CD   NaN   NaN   NaN   NaN   NaN   NaN  ...   3491.204325
# 261  NY.GDP.PCAP.PP.CD   NaN   NaN   NaN   NaN   NaN   NaN  ...  12057.268709
# 262  NY.GDP.PCAP.PP.CD   NaN   NaN   NaN   NaN   NaN   NaN  ...   3422.626326
# 263  NY.GDP.PCAP.PP.CD   NaN   NaN   NaN   NaN   NaN   NaN  ...   2375.930267
#
#              2013          2014          2015          2016          2017  \
# 0    36477.779389  36444.262057  36765.116071  37359.373438  38442.413838
# 1     2015.514962   2069.424642   2087.305323   1981.112469   2058.383832
# 2     7682.477158   8179.296007   7337.569559   7103.225938   7310.901738
# 3    10570.968104  11259.296700  11658.866060  12078.800728  12811.759436
# 4             NaN           NaN           NaN           NaN           NaN
# ..            ...           ...           ...           ...           ...
# 259   8805.379754   9043.183283   9575.754880  10062.108264  10530.481665
# 260   3688.519849           NaN           NaN           NaN           NaN
# 261  12450.497503  12520.713748  12552.340127  12592.486871  12703.421242
# 262   3578.858324   3539.445584   3430.402231   3404.661922   3485.005238
# 263   2560.777487   2612.461530   2679.510136   2806.458631   3028.245976
#
#              2018          2019  2020  Unnamed: 65
# 0             NaN           NaN   NaN          NaN
# 1     2083.321897   2156.419482   NaN          NaN
# 2     7102.405887   6965.511374   NaN          NaN
# 3    13974.011607  14648.267402   NaN          NaN
# 4             NaN           NaN   NaN          NaN
# ..            ...           ...   ...          ...
# 259  11160.695332  11870.797576   NaN          NaN
# 260           NaN           NaN   NaN          NaN
# 261  12938.432733  13034.164661   NaN          NaN
# 262   3607.304442   3624.024939   NaN          NaN
# 263   3206.277079   2961.446428   NaN          NaN
#
# [264 rows x 66 columns]
